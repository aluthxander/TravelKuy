# %%
import numpy as np
import pandas as pd 

# Untuk visualisasi data
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline
sns.set_palette('Set1')
sns.set()

# Untuk pemodelan
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Untuk menghilangkan warnings saat plotting seaborn
import warnings
warnings.filterwarnings('ignore')
# Out:
# 2022-05-18 21:44:41.357712: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-05-18 21:44:41.357756: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
package = pd.read_csv('data/package_tourism.csv')
rating = pd.read_csv('data/tourism_rating.csv')
place = pd.read_csv('data/tourism_with_id.csv')
user = pd.read_csv('data/user.csv')

# %%
# Melihat gambaran data place

place.head()
# Out:
#    Place_Id                         Place_Name  \
# 0         1                   Monumen Nasional
# 1         2                           Kota Tua
# 2         3                      Dunia Fantasi
# 3         4  Taman Mini Indonesia Indah (TMII)
# 4         5           Atlantis Water Adventure
#
#                                          Description       Category     City  \
# 0  Monumen Nasional atau yang populer disingkat d...         Budaya  Jakarta
# 1  Kota tua di Jakarta, yang juga bernama Kota Tu...         Budaya  Jakarta
# 2  Dunia Fantasi atau disebut juga Dufan adalah t...  Taman Hiburan  Jakarta
# 3  Taman Mini Indonesia Indah merupakan suatu kaw...  Taman Hiburan  Jakarta
# 4  Atlantis Water Adventure atau dikenal dengan A...  Taman Hiburan  Jakarta
#
#    Rating  Time_Minutes                                       Coordinate  \
# 0     4.6          15.0          {'lat': -6.1753924, 'lng': 106.8271528}
# 1     4.6          90.0  {'lat': -6.137644799999999, 'lng': 106.8171245}
# 2     4.6         360.0  {'lat': -6.125312399999999, 'lng': 106.8335377}
# 3     4.5           NaN  {'lat': -6.302445899999999, 'lng': 106.8951559}
# 4     4.5          60.0             {'lat': -6.12419, 'lng': 106.839134}
#
#         Lat        Long   Price  Unnamed: 11
# 0 -6.175392  106.827153   20000            1
# 1 -6.137645  106.817125       0            2
# 2 -6.125312  106.833538  270000            3
# 3 -6.302446  106.895156   10000            4
# 4 -6.124190  106.839134   94000            5

# %%
# Membuang kolom yang tidak dipakai

place = place.drop(['Unnamed: 11'],axis=1)
place.head()
# Out:
#    Place_Id                         Place_Name  \
# 0         1                   Monumen Nasional
# 1         2                           Kota Tua
# 2         3                      Dunia Fantasi
# 3         4  Taman Mini Indonesia Indah (TMII)
# 4         5           Atlantis Water Adventure
#
#                                          Description       Category     City  \
# 0  Monumen Nasional atau yang populer disingkat d...         Budaya  Jakarta
# 1  Kota tua di Jakarta, yang juga bernama Kota Tu...         Budaya  Jakarta
# 2  Dunia Fantasi atau disebut juga Dufan adalah t...  Taman Hiburan  Jakarta
# 3  Taman Mini Indonesia Indah merupakan suatu kaw...  Taman Hiburan  Jakarta
# 4  Atlantis Water Adventure atau dikenal dengan A...  Taman Hiburan  Jakarta
#
#    Rating  Time_Minutes                                       Coordinate  \
# 0     4.6          15.0          {'lat': -6.1753924, 'lng': 106.8271528}
# 1     4.6          90.0  {'lat': -6.137644799999999, 'lng': 106.8171245}
# 2     4.6         360.0  {'lat': -6.125312399999999, 'lng': 106.8335377}
# 3     4.5           NaN  {'lat': -6.302445899999999, 'lng': 106.8951559}
# 4     4.5          60.0             {'lat': -6.12419, 'lng': 106.839134}
#
#         Lat        Long   Price
# 0 -6.175392  106.827153   20000
# 1 -6.137645  106.817125       0
# 2 -6.125312  106.833538  270000
# 3 -6.302446  106.895156   10000
# 4 -6.124190  106.839134   94000

# %%
# Merubah data agar hanya dari Kota Bandung

place = place[place['City']=='Yogyakarta']
place.head(2)
# Out:
#     Place_Id               Place_Name  \
# 84        85  Taman Pintar Yogyakarta
# 85        86       Keraton Yogyakarta
#
#                                           Description       Category  \
# 84  Taman Pintar Yogyakarta (bahasa Jawa: Hanacara...  Taman Hiburan
# 85  Keraton Ngayogyakarta Hadiningrat atau Keraton...         Budaya
#
#           City  Rating  Time_Minutes  \
# 84  Yogyakarta     4.5         120.0
# 85  Yogyakarta     4.6           NaN
#
#                                          Coordinate       Lat        Long  \
# 84  {'lat': -7.800671500000001, 'lng': 110.3676551} -7.800671  110.367655
# 85          {'lat': -7.8052845, 'lng': 110.3642031} -7.805284  110.364203
#
#     Price
# 84   6000
# 85  15000

# %%
# Membuang kolom yang tidak dipakai

place = place.drop('Time_Minutes', axis=1)

# %%
# melihat gambaran data rating

rating.head()
# Out:
#    User_Id  Place_Id  Place_Ratings
# 0        1       179              3
# 1        1       344              2
# 2        1         5              5
# 3        1       373              3
# 4        1       101              4

# %%
# Merubah data rating agar hanya berisi rating pada tempat wisata dari Kota Yogyakarta

rating = pd.merge(rating, place[['Place_Id']], how='right', on='Place_Id')
rating.head()
# Out:
#    User_Id  Place_Id  Place_Ratings
# 0        2        85              4
# 1       23        85              4
# 2       25        85              2
# 3       39        85              5
# 4       43        85              4

# %%
# Melihat ukuran dataset rating untuk Kota Yogyakarta

rating.shape
# Out:
# (2871, 3)

# %%
# Melihat gambaran data user

user.head()
# Out:
#    User_Id                   Location  Age
# 0        1      Semarang, Jawa Tengah   20
# 1        2         Bekasi, Jawa Barat   21
# 2        3        Cirebon, Jawa Barat   23
# 3        4         Bekasi, Jawa Barat   21
# 4        5  Lampung, Sumatera Selatan   20

# %%
# Merubah data user agar hanya berisi user yang pernah megunjungi wisata di Kota Yogyakarta

user = pd.merge(user, rating[['User_Id']], how='right', on='User_Id').drop_duplicates().sort_values('User_Id')
user.head()
# Out:
#      User_Id                   Location  Age
# 101        1      Semarang, Jawa Tengah   20
# 0          2         Bekasi, Jawa Barat   21
# 25         3        Cirebon, Jawa Barat   23
# 69         4         Bekasi, Jawa Barat   21
# 717        5  Lampung, Sumatera Selatan   20

# %%
# Melihat dataset user yang pernah memberi rating pada wisata di Kota Yogyakarta

user.shape
# Out:
# (300, 3)

# %%
# Membuat dataframe berisi lokasi dengan jumlah rating terbanyak
top_10 = rating['Place_Id'].value_counts().reset_index()[0:10]
top_10 = pd.merge(top_10, place[['Place_Id','Place_Name']], how='left', left_on='index', right_on='Place_Id')

# Membuat visualisasi wisata dengan jumlah rating terbanyak
plt.figure(figsize=(8,5))
sns.barplot('Place_Id_x', 'Place_Name', data=top_10)
plt.title('Jumlah Tempat Wisata dengan Rating Terbanyak', pad=20)
plt.ylabel('Jumlah Rating')
plt.xlabel('Nama Lokasi')
plt.show()

# %%
# Membuat visualisasi jumlah kategori wisata di Kota Yogyakarta

sns.countplot(y='Category', data=place)
plt.title('Perbandingan Jumlah Kategori Wisata di Kota Yogyakarta', pad=20)
plt.show()

# %%
# Membuat visualisasi distribusi usia user

plt.figure(figsize=(5,3))
sns.boxplot(user['Age']);
plt.title('Distribusi Usia User', pad=20)
plt.show()

# %%
# Membuat visualisasi distribusi harga masuk tempat wisata

plt.figure(figsize=(7,3))
sns.boxplot(place['Price'])
plt.title('Distribusi Harga Masuk Wisata di Kota Yogyakarta', pad=20)
plt.show()

# %%
# Memfilter asal kota dari user
askot = user['Location'].apply(lambda x : x.split(',')[0])

# Visualisasi asal kota dari user
plt.figure(figsize=(8,6))
sns.countplot(y=askot)
plt.title('Jumlah Asal Kota dari User')
plt.show()

# %% [markdown]
#  # MODELING

# %%
# Membaca dataset untuk dilakukan encoding
 
df = rating.copy()
df.head()
# Out:
#    User_Id  Place_Id  Place_Ratings
# 0        2        85              4
# 1       23        85              4
# 2       25        85              2
# 3       39        85              5
# 4       43        85              4

# %%
#ENCODING
def dict_encoder(col, data=df):

  # Mengubah kolom suatu dataframe menjadi list tanpa nilai yang sama
  unique_val = data[col].unique().tolist()

  # Melakukan encoding value kolom suatu dataframe ke angka
  val_to_val_encoded = {x: i for i, x in enumerate(unique_val)}

  # Melakukan proses encoding angka ke value dari kolom suatu dataframe
  val_encoded_to_val = {i: x for i, x in enumerate(unique_val)}
  return val_to_val_encoded, val_encoded_to_val

# %%
# ENCODING + MAPING 

# Encoding User_Id
user_to_user_encoded, user_encoded_to_user = dict_encoder('User_Id')

# Mapping User_Id ke dataframe
df['user'] = df['User_Id'].map(user_to_user_encoded)

# %%
# Encoding Place_Id
place_to_place_encoded, place_encoded_to_place = dict_encoder('Place_Id')

# Mapping Place_Id ke dataframe place
df['place'] = df['Place_Id'].map(place_to_place_encoded)

# %%
# Mendapatkan jumlah user dan place
num_users, num_place = len(user_to_user_encoded), len(place_to_place_encoded)
 
# Mengubah rating menjadi nilai float
df['Place_Ratings'] = df['Place_Ratings'].values.astype(np.float32)
 
# Mendapatkan nilai minimum dan maksimum rating
min_rating, max_rating = min(df['Place_Ratings']), max(df['Place_Ratings'])
 
print(f'Number of User: {num_users}, Number of Place: {num_place}, Min Rating: {min_rating}, Max Rating: {max_rating}')
# Out:
# Number of User: 300, Number of Place: 126, Min Rating: 1.0, Max Rating: 5.0

# %%
# Mengacak dataset
df = df.sample(frac=1, random_state=42)
df.head(2)
# Out:
#       User_Id  Place_Id  Place_Ratings  user  place
# 729       194       115            4.0   130     30
# 2067      276       176            2.0    23     91

# %%
# Membuat variabel x untuk mencocokkan data user dan place menjadi satu value
x = df[['user', 'place']].values
 
# Membuat variabel y untuk membuat rating dari hasil 
y = df['Place_Ratings'].apply(lambda x: (x - min_rating) / (max_rating - min_rating)).values
 
# Membagi menjadi 80% data train dan 20% data validasi
train_indices = int(0.8 * df.shape[0])
x_train, x_val, y_train, y_val = (
    x[:train_indices],
    x[train_indices:],
    y[:train_indices],
    y[train_indices:]
)

# %%
class RecommenderNet(tf.keras.Model):
 
  # Insialisasi fungsi
  def __init__(self, num_users, num_places, embedding_size, **kwargs):
    super(RecommenderNet, self).__init__(**kwargs)
    self.num_users = num_users
    self.num_places = num_places
    self.embedding_size = embedding_size
    self.user_embedding = layers.Embedding( # layer embedding user
        num_users,
        embedding_size,
        embeddings_initializer = 'he_normal',
        embeddings_regularizer = keras.regularizers.l2(1e-6)
    )
    self.user_bias = layers.Embedding(num_users, 1) # layer embedding user bias
    self.places_embedding = layers.Embedding( # layer embeddings places
        num_places,
        embedding_size,
        embeddings_initializer = 'he_normal',
        embeddings_regularizer = keras.regularizers.l2(1e-6)
    )
    self.places_bias = layers.Embedding(num_places, 1) # layer embedding places bias
 
  def call(self, inputs):
    user_vector = self.user_embedding(inputs[:,0]) # memanggil layer embedding 1
    user_bias = self.user_bias(inputs[:, 0]) # memanggil layer embedding 2
    places_vector = self.places_embedding(inputs[:, 1]) # memanggil layer embedding 3
    places_bias = self.places_bias(inputs[:, 1]) # memanggil layer embedding 4
 
    dot_user_places = tf.tensordot(user_vector, places_vector, 2) 
 
    x = dot_user_places + user_bias + places_bias
    
    return tf.nn.sigmoid(x) # activation sigmoid

# %%
model = RecommenderNet(num_users, num_place, 50) # inisialisasi model
 
# model compile
model.compile(
    loss = tf.keras.losses.BinaryCrossentropy(),
    optimizer = keras.optimizers.Adam(learning_rate=0.0004),
    metrics=[tf.keras.metrics.RootMeanSquaredError()]
)
# Out:
# 2022-05-18 21:56:46.558848: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-05-18 21:56:46.558894: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-05-18 21:56:46.558930: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (noogler): /proc/driver/nvidia/version does not exist

# %%
 class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('val_root_mean_squared_error')<0.25):
      print('Lapor! Metriks validasi sudah sesuai harapan')
      self.model.stop_training = True

# %%
# Memulai training
 
history = model.fit(
    x = x_train,
    y = y_train,
    epochs = 100,
    validation_data = (x_val, y_val),
    callbacks = [myCallback()]
)
# Out:
# Epoch 1/100
# 72/72 [==============================] - 2s 11ms/step - loss: 0.7289 - root_mean_squared_error: 0.3733 - val_loss: 0.7242 - val_root_mean_squared_error: 0.3616
# Epoch 2/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.7130 - root_mean_squared_error: 0.3642 - val_loss: 0.7219 - val_root_mean_squared_error: 0.3602
# Epoch 3/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.7071 - root_mean_squared_error: 0.3606 - val_loss: 0.7214 - val_root_mean_squared_error: 0.3599
# Epoch 4/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.7114 - root_mean_squared_error: 0.3633 - val_loss: 0.7215 - val_root_mean_squared_error: 0.3599
# Epoch 5/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.7031 - root_mean_squared_error: 0.3579 - val_loss: 0.7218 - val_root_mean_squared_error: 0.3601
# Epoch 6/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.7111 - root_mean_squared_error: 0.3633 - val_loss: 0.7230 - val_root_mean_squared_error: 0.3609
# Epoch 7/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.7106 - root_mean_squared_error: 0.3627 - val_loss: 0.7228 - val_root_mean_squared_error: 0.3607
# Epoch 8/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.7023 - root_mean_squared_error: 0.3572 - val_loss: 0.7224 - val_root_mean_squared_error: 0.3605
# Epoch 9/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6956 - root_mean_squared_error: 0.3529 - val_loss: 0.7224 - val_root_mean_squared_error: 0.3605
# Epoch 10/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.7068 - root_mean_squared_error: 0.3604 - val_loss: 0.7225 - val_root_mean_squared_error: 0.3606
# Epoch 11/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.7007 - root_mean_squared_error: 0.3564 - val_loss: 0.7222 - val_root_mean_squared_error: 0.3604
# Epoch 12/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6969 - root_mean_squared_error: 0.3538 - val_loss: 0.7222 - val_root_mean_squared_error: 0.3605
# Epoch 13/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6967 - root_mean_squared_error: 0.3535 - val_loss: 0.7210 - val_root_mean_squared_error: 0.3597
# Epoch 14/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6995 - root_mean_squared_error: 0.3552 - val_loss: 0.7212 - val_root_mean_squared_error: 0.3598
# Epoch 15/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6935 - root_mean_squared_error: 0.3514 - val_loss: 0.7210 - val_root_mean_squared_error: 0.3597
# Epoch 16/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6911 - root_mean_squared_error: 0.3498 - val_loss: 0.7211 - val_root_mean_squared_error: 0.3597
# Epoch 17/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6915 - root_mean_squared_error: 0.3500 - val_loss: 0.7205 - val_root_mean_squared_error: 0.3593
# Epoch 18/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6893 - root_mean_squared_error: 0.3485 - val_loss: 0.7199 - val_root_mean_squared_error: 0.3590
# Epoch 19/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6913 - root_mean_squared_error: 0.3498 - val_loss: 0.7200 - val_root_mean_squared_error: 0.3591
# Epoch 20/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6853 - root_mean_squared_error: 0.3457 - val_loss: 0.7203 - val_root_mean_squared_error: 0.3593
# Epoch 21/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6869 - root_mean_squared_error: 0.3468 - val_loss: 0.7195 - val_root_mean_squared_error: 0.3587
# Epoch 22/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6855 - root_mean_squared_error: 0.3459 - val_loss: 0.7189 - val_root_mean_squared_error: 0.3584
# Epoch 23/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6854 - root_mean_squared_error: 0.3458 - val_loss: 0.7182 - val_root_mean_squared_error: 0.3579
# Epoch 24/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6848 - root_mean_squared_error: 0.3454 - val_loss: 0.7184 - val_root_mean_squared_error: 0.3580
# Epoch 25/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6826 - root_mean_squared_error: 0.3438 - val_loss: 0.7180 - val_root_mean_squared_error: 0.3578
# Epoch 26/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6812 - root_mean_squared_error: 0.3428 - val_loss: 0.7176 - val_root_mean_squared_error: 0.3576
# Epoch 27/100
# 72/72 [==============================] - 0s 5ms/step - loss: 0.6787 - root_mean_squared_error: 0.3410 - val_loss: 0.7174 - val_root_mean_squared_error: 0.3574
# Epoch 28/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6820 - root_mean_squared_error: 0.3433 - val_loss: 0.7181 - val_root_mean_squared_error: 0.3578
# Epoch 29/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6822 - root_mean_squared_error: 0.3435 - val_loss: 0.7180 - val_root_mean_squared_error: 0.3578
# Epoch 30/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6793 - root_mean_squared_error: 0.3415 - val_loss: 0.7177 - val_root_mean_squared_error: 0.3576
# Epoch 31/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6799 - root_mean_squared_error: 0.3418 - val_loss: 0.7177 - val_root_mean_squared_error: 0.3575
# Epoch 32/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6801 - root_mean_squared_error: 0.3420 - val_loss: 0.7177 - val_root_mean_squared_error: 0.3575
# Epoch 33/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6754 - root_mean_squared_error: 0.3387 - val_loss: 0.7193 - val_root_mean_squared_error: 0.3585
# Epoch 34/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6768 - root_mean_squared_error: 0.3397 - val_loss: 0.7191 - val_root_mean_squared_error: 0.3584
# Epoch 35/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6776 - root_mean_squared_error: 0.3402 - val_loss: 0.7181 - val_root_mean_squared_error: 0.3577
# Epoch 36/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6758 - root_mean_squared_error: 0.3390 - val_loss: 0.7190 - val_root_mean_squared_error: 0.3582
# Epoch 37/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6732 - root_mean_squared_error: 0.3370 - val_loss: 0.7181 - val_root_mean_squared_error: 0.3577
# Epoch 38/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6742 - root_mean_squared_error: 0.3378 - val_loss: 0.7189 - val_root_mean_squared_error: 0.3581
# Epoch 39/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6739 - root_mean_squared_error: 0.3376 - val_loss: 0.7197 - val_root_mean_squared_error: 0.3587
# Epoch 40/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6714 - root_mean_squared_error: 0.3357 - val_loss: 0.7201 - val_root_mean_squared_error: 0.3589
# Epoch 41/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6742 - root_mean_squared_error: 0.3378 - val_loss: 0.7205 - val_root_mean_squared_error: 0.3591
# Epoch 42/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6739 - root_mean_squared_error: 0.3375 - val_loss: 0.7211 - val_root_mean_squared_error: 0.3595
# Epoch 43/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6734 - root_mean_squared_error: 0.3372 - val_loss: 0.7215 - val_root_mean_squared_error: 0.3598
# Epoch 44/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6696 - root_mean_squared_error: 0.3344 - val_loss: 0.7210 - val_root_mean_squared_error: 0.3594
# Epoch 45/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6682 - root_mean_squared_error: 0.3334 - val_loss: 0.7220 - val_root_mean_squared_error: 0.3601
# Epoch 46/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6672 - root_mean_squared_error: 0.3327 - val_loss: 0.7215 - val_root_mean_squared_error: 0.3598
# Epoch 47/100
# 72/72 [==============================] - 0s 5ms/step - loss: 0.6722 - root_mean_squared_error: 0.3364 - val_loss: 0.7205 - val_root_mean_squared_error: 0.3592
# Epoch 48/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6688 - root_mean_squared_error: 0.3338 - val_loss: 0.7209 - val_root_mean_squared_error: 0.3594
# Epoch 49/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6694 - root_mean_squared_error: 0.3343 - val_loss: 0.7211 - val_root_mean_squared_error: 0.3595
# Epoch 50/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6689 - root_mean_squared_error: 0.3339 - val_loss: 0.7215 - val_root_mean_squared_error: 0.3597
# Epoch 51/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6695 - root_mean_squared_error: 0.3344 - val_loss: 0.7212 - val_root_mean_squared_error: 0.3596
# Epoch 52/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6679 - root_mean_squared_error: 0.3331 - val_loss: 0.7218 - val_root_mean_squared_error: 0.3599
# Epoch 53/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6654 - root_mean_squared_error: 0.3314 - val_loss: 0.7212 - val_root_mean_squared_error: 0.3595
# Epoch 54/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6644 - root_mean_squared_error: 0.3307 - val_loss: 0.7212 - val_root_mean_squared_error: 0.3595
# Epoch 55/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6683 - root_mean_squared_error: 0.3335 - val_loss: 0.7210 - val_root_mean_squared_error: 0.3593
# Epoch 56/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6675 - root_mean_squared_error: 0.3328 - val_loss: 0.7207 - val_root_mean_squared_error: 0.3592
# Epoch 57/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6644 - root_mean_squared_error: 0.3307 - val_loss: 0.7213 - val_root_mean_squared_error: 0.3596
# Epoch 58/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6632 - root_mean_squared_error: 0.3298 - val_loss: 0.7222 - val_root_mean_squared_error: 0.3601
# Epoch 59/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6624 - root_mean_squared_error: 0.3292 - val_loss: 0.7229 - val_root_mean_squared_error: 0.3605
# Epoch 60/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6639 - root_mean_squared_error: 0.3302 - val_loss: 0.7224 - val_root_mean_squared_error: 0.3601
# Epoch 61/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6639 - root_mean_squared_error: 0.3303 - val_loss: 0.7223 - val_root_mean_squared_error: 0.3601
# Epoch 62/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6626 - root_mean_squared_error: 0.3294 - val_loss: 0.7230 - val_root_mean_squared_error: 0.3605
# Epoch 63/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6626 - root_mean_squared_error: 0.3294 - val_loss: 0.7229 - val_root_mean_squared_error: 0.3605
# Epoch 64/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6616 - root_mean_squared_error: 0.3287 - val_loss: 0.7233 - val_root_mean_squared_error: 0.3607
# Epoch 65/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6635 - root_mean_squared_error: 0.3300 - val_loss: 0.7233 - val_root_mean_squared_error: 0.3606
# Epoch 66/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6606 - root_mean_squared_error: 0.3278 - val_loss: 0.7229 - val_root_mean_squared_error: 0.3604
# Epoch 67/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6608 - root_mean_squared_error: 0.3281 - val_loss: 0.7227 - val_root_mean_squared_error: 0.3602
# Epoch 68/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6597 - root_mean_squared_error: 0.3272 - val_loss: 0.7236 - val_root_mean_squared_error: 0.3608
# Epoch 69/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6616 - root_mean_squared_error: 0.3285 - val_loss: 0.7239 - val_root_mean_squared_error: 0.3609
# Epoch 70/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6615 - root_mean_squared_error: 0.3285 - val_loss: 0.7237 - val_root_mean_squared_error: 0.3608
# Epoch 71/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6600 - root_mean_squared_error: 0.3274 - val_loss: 0.7237 - val_root_mean_squared_error: 0.3608
# Epoch 72/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6605 - root_mean_squared_error: 0.3278 - val_loss: 0.7244 - val_root_mean_squared_error: 0.3612
# Epoch 73/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6597 - root_mean_squared_error: 0.3272 - val_loss: 0.7245 - val_root_mean_squared_error: 0.3613
# Epoch 74/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6591 - root_mean_squared_error: 0.3268 - val_loss: 0.7247 - val_root_mean_squared_error: 0.3615
# Epoch 75/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6590 - root_mean_squared_error: 0.3267 - val_loss: 0.7249 - val_root_mean_squared_error: 0.3616
# Epoch 76/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6606 - root_mean_squared_error: 0.3279 - val_loss: 0.7255 - val_root_mean_squared_error: 0.3620
# Epoch 77/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6579 - root_mean_squared_error: 0.3260 - val_loss: 0.7261 - val_root_mean_squared_error: 0.3623
# Epoch 78/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6561 - root_mean_squared_error: 0.3246 - val_loss: 0.7258 - val_root_mean_squared_error: 0.3622
# Epoch 79/100
# 72/72 [==============================] - 0s 5ms/step - loss: 0.6565 - root_mean_squared_error: 0.3249 - val_loss: 0.7256 - val_root_mean_squared_error: 0.3620
# Epoch 80/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6567 - root_mean_squared_error: 0.3251 - val_loss: 0.7250 - val_root_mean_squared_error: 0.3616
# Epoch 81/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6590 - root_mean_squared_error: 0.3268 - val_loss: 0.7260 - val_root_mean_squared_error: 0.3623
# Epoch 82/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6546 - root_mean_squared_error: 0.3235 - val_loss: 0.7255 - val_root_mean_squared_error: 0.3620
# Epoch 83/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6549 - root_mean_squared_error: 0.3236 - val_loss: 0.7250 - val_root_mean_squared_error: 0.3617
# Epoch 84/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6571 - root_mean_squared_error: 0.3253 - val_loss: 0.7251 - val_root_mean_squared_error: 0.3618
# Epoch 85/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6554 - root_mean_squared_error: 0.3241 - val_loss: 0.7254 - val_root_mean_squared_error: 0.3619
# Epoch 86/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6546 - root_mean_squared_error: 0.3234 - val_loss: 0.7250 - val_root_mean_squared_error: 0.3617
# Epoch 87/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6560 - root_mean_squared_error: 0.3245 - val_loss: 0.7263 - val_root_mean_squared_error: 0.3625
# Epoch 88/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6569 - root_mean_squared_error: 0.3251 - val_loss: 0.7266 - val_root_mean_squared_error: 0.3627
# Epoch 89/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6560 - root_mean_squared_error: 0.3245 - val_loss: 0.7265 - val_root_mean_squared_error: 0.3626
# Epoch 90/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6529 - root_mean_squared_error: 0.3222 - val_loss: 0.7264 - val_root_mean_squared_error: 0.3625
# Epoch 91/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6541 - root_mean_squared_error: 0.3230 - val_loss: 0.7258 - val_root_mean_squared_error: 0.3621
# Epoch 92/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6539 - root_mean_squared_error: 0.3230 - val_loss: 0.7263 - val_root_mean_squared_error: 0.3624
# Epoch 93/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6549 - root_mean_squared_error: 0.3237 - val_loss: 0.7261 - val_root_mean_squared_error: 0.3623
# Epoch 94/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6556 - root_mean_squared_error: 0.3242 - val_loss: 0.7265 - val_root_mean_squared_error: 0.3624
# Epoch 95/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6549 - root_mean_squared_error: 0.3237 - val_loss: 0.7263 - val_root_mean_squared_error: 0.3623
# Epoch 96/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6540 - root_mean_squared_error: 0.3231 - val_loss: 0.7258 - val_root_mean_squared_error: 0.3619
# Epoch 97/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6551 - root_mean_squared_error: 0.3239 - val_loss: 0.7256 - val_root_mean_squared_error: 0.3618
# Epoch 98/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6553 - root_mean_squared_error: 0.3240 - val_loss: 0.7255 - val_root_mean_squared_error: 0.3617
# Epoch 99/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6556 - root_mean_squared_error: 0.3242 - val_loss: 0.7257 - val_root_mean_squared_error: 0.3618
# Epoch 100/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6540 - root_mean_squared_error: 0.3231 - val_loss: 0.7253 - val_root_mean_squared_error: 0.3616

# %%
model.evaluate(x=x_val, y=y_val)
# Out:
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7253 - root_mean_squared_error: 0.3616
# [0.7253347039222717, 0.3615992069244385]

# %%
model.save_weights('my_model.h5')

# %%
# Menampilkan plot loss dan validation

plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title('model_metrics')
plt.ylabel('root_mean_squared_error')
plt.xlabel('epoch')
plt.ylim(ymin=0, ymax=0.4)
plt.legend(['train', 'test'], loc='center left')
plt.show()

# %% [markdown]
# # MEMBUAT TOP 5 REKOMENDASI

# %%
# Menyiapkan dataframe
place_df = place[['Place_Id','Place_Name','Category','Rating','Price']]
place_df.columns = ['id','place_name','category','rating','price']
df = rating.copy()

# %%
# Mengambil sample user
user_id = df.User_Id.sample(1).iloc[0]
place_visited_by_user = df[df.User_Id == user_id]

# %%
# Membuat data lokasi yang belum dikunjungi user
place_not_visited = place_df[~place_df['id'].isin(place_visited_by_user.Place_Id.values)]['id'] 
place_not_visited = list(
    set(place_not_visited)
    .intersection(set(place_to_place_encoded.keys()))
)
 
place_not_visited = [[place_to_place_encoded.get(x)] for x in place_not_visited]
user_encoder = user_to_user_encoded.get(user_id)
user_place_array = np.hstack(
    ([[user_encoder]] * len(place_not_visited), place_not_visited)
)

# %%
# Mengambil top 5 recommendation
ratings = model.predict(user_place_array).flatten()
top_ratings_indices = ratings.argsort()[-5:][::-1]
recommended_place_ids = [
    place_encoded_to_place.get(place_not_visited[x][0]) for x in top_ratings_indices
]
 
print('Daftar rekomendasi untuk: {}'.format('User ' + str(user_id)))
print('===' * 15,'\n')
print('----' * 15)
print('Tempat dengan rating wisata paling tinggi dari user')
print('----' * 15)
 
top_place_user = (
    place_visited_by_user.sort_values(
        by = 'Place_Ratings',
        ascending=False
    )
    .head(5)
    .Place_Id.values
)
 
place_df_rows = place_df[place_df['id'].isin(top_place_user)]
for row in place_df_rows.itertuples():
    print(row.place_name, ':', row.category)

print('')
print('----' * 15)
print('Top 5 place recommendation')
print('----' * 15)
 
recommended_place = place_df[place_df['id'].isin(recommended_place_ids)]
for row, i in zip(recommended_place.itertuples(), range(1,8)):
    print(i,'.', row.place_name, '\n    ', row.category, ',', 'Harga Tiket Masuk ', row.price, ',', 'Rating Wisata ', row.rating,'\n')

print('==='*15)
# Out:
# Daftar rekomendasi untuk: User 263
# =============================================
#
# ------------------------------------------------------------
# Tempat dengan rating wisata paling tinggi dari user
# ------------------------------------------------------------
# Gembira Loka Zoo : Cagar Alam
# Monumen Sanapati : Budaya
# Bukit Panguk Kediwung : Budaya
# Candi Prambanan : Budaya
# Air Terjun Sri Gethuk : Cagar Alam
#
# ------------------------------------------------------------
# Top 5 place recommendation
# ------------------------------------------------------------
# 1 . Monumen Yogya Kembali
#      Budaya , Harga Tiket Masuk  15000 , Rating Wisata  4.5
#
# 2 . Bukit Bintang Yogyakarta
#      Taman Hiburan , Harga Tiket Masuk  25000 , Rating Wisata  4.5
#
# 3 . The World Landmarks - Merapi Park Yogyakarta
#      Taman Hiburan , Harga Tiket Masuk  22000 , Rating Wisata  4.2
#
# 4 . Pantai Baron
#      Bahari , Harga Tiket Masuk  10000 , Rating Wisata  4.4
#
# 5 . Pintoe Langit Dahromo
#      Cagar Alam , Harga Tiket Masuk  2500 , Rating Wisata  4.4
#
# =============================================

# %%
recommended_place
# Out:
#       id                                    place_name       category  rating  \
# 96    97                         Monumen Yogya Kembali         Budaya     4.5
# 111  112                      Bukit Bintang Yogyakarta  Taman Hiburan     4.5
# 116  117  The World Landmarks - Merapi Park Yogyakarta  Taman Hiburan     4.2
# 156  157                                  Pantai Baron         Bahari     4.4
# 163  164                         Pintoe Langit Dahromo     Cagar Alam     4.4
#
#      price
# 96   15000
# 111  25000
# 116  22000
# 156  10000
# 163   2500
